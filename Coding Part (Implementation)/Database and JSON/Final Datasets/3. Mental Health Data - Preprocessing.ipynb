# %%
# mount the drive to access files which are on drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# get the path
path = "/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Main_Data/MentalHealth_QA.csv"

# %%
# importing pandas
import pandas as pd

# loading the dataframe
df = pd.read_csv(path)

# check for the data
df.head()
# Out:
#    Unnamed: 0  ...                                            Answers
# 0           0  ...  It sounds like you are wanting to protect your...
# 1           1  ...  First of all, my heart goes out to you. Infide...
# 2           2  ...  Crying due to a dissolution of a marriage, is ...
# 3           3  ...  It all depends how old you are and what a part...
# 4           4  ...  Well, then your decision is whether you want t...
#
# [5 rows x 3 columns]

# %%
# delete the column "Unnamed : 0"
df = df.drop(['Unnamed: 0'], axis=1)

# %%
# check for the result
df.head()
# Out:
#                                            Questions                                            Answers
# 0  A friend of my child's father is sending him i...  It sounds like you are wanting to protect your...
# 1  About a year ago I found out my husband had ch...  First of all, my heart goes out to you. Infide...
# 2                All I can do is cry and hate myself  Crying due to a dissolution of a marriage, is ...
# 3              Am I a lesbian because I love a girl?  It all depends how old you are and what a part...
# 4    Am I being picky when it comes to my boyfriend?  Well, then your decision is whether you want t...

# %%
# import the nltk libraries
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# import the regular expression library
import re

# Create a function to clean the Questions and Answers
def clean_text(text):
    
    # clean the text
    res = text.lower()
    res = re.sub(r"i'm", "i am", res)
    res = re.sub(r"he's", "he is", res)
    res = re.sub(r"she's", "she is", res)
    res = re.sub(r"i'll", "i will", res)
    res = re.sub(r"it's", "it is", res)
    res = re.sub(r"that's", "that is", res)
    res = re.sub(r"where's", "where is", res)
    res = re.sub(r"how's", "how is", res)
    res = re.sub(r"\'ll", " will", res)
    res = re.sub(r"\'ve", " have", res)
    res = re.sub(r"\'re", " are", res)
    res = re.sub(r"\'d", " would", res)
    res = re.sub(r"\'re", " are", res)
    res = re.sub(r"won't", "will not", res)
    res = re.sub(r"can't", "cannot", res)
    res = re.sub(r"n't", " not", res)
    res = re.sub(r"n'", "ng", res)
    res = re.sub(r"'bout", "about", res)
    res = re.sub(r"'til", "until", res)
    res = re.sub("[\(\[].*?[\)\]]", "", res)
    res = re.sub(r"{.*}", "", res)
    res = re.sub(r"  ", " ", res)
    res = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", res)

    # return the clean text
    return res

# %%
# clean all the question

# initialize the index
index = 0

# clean and store the result
for question in df['Questions']:

    # clean each question
    question = clean_text(question)

    # store each question
    df['Questions'][index] = question

    # increament the index
    index += 1

# %%
# clean all the answers

# initialize the index
index = 0

# clean and store the result
for answer in df['Answers']:

    # clean each answer
    answer = clean_text(answer)

    # store each answer
    df['Answers'][index] = answer

    # increament the index
    index += 1

# %%
df.head()
# Out:
#                                            Questions                                            Answers
# 0  a friend of my child's father is sending him i...  it sounds like you are wanting to protect your...
# 1  about a year ago i found out my husband had ch...  first of all my heart goes out to you infideli...
# 2                all i can do is cry and hate myself  crying due to a dissolution of a marriage is n...
# 3               am i a lesbian because i love a girl  it all depends how old you are and what a part...
# 4     am i being picky when it comes to my boyfriend  well then your decision is whether you want to...

# %%
# convert this file to csv file
df.to_csv('/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Final Datasets/3. Mental-Health-QA Preprocessing.csv')

# %%
# file successfully exported to the mentioned path
# path = /content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Final Datasets/3. Mental-Health-QA Preprocessing.csv

# %%
# PRE - PROCESSING IS DONE!!!!
