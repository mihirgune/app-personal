# %%
# mount the drive to access files which are on drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# get the path
path = "/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Main_Data/Normal_QA.csv"

# %%
# importing pandas
import pandas as pd

# loading the dataframe
df = pd.read_csv(path)

# check for the data
df.head()
# Out:
#    Unnamed: 0                           Questions                      Answers
# 0           0            What are you working on?          I am baking a cake.
# 1           1  Errors should never pass silently.  Unless explicitly silenced.
# 2           2     I am doing well, how about you?              I am also good.
# 3           3    What kind of movies do you like?          Alice in Wonderland
# 4           4                               Hello                           Hi

# %%
# delete the column "Unnamed : 0"
df = df.drop(['Unnamed: 0'], axis=1)

# %%
# check for the result
df.head()
# Out:
#                             Questions                      Answers
# 0            What are you working on?          I am baking a cake.
# 1  Errors should never pass silently.  Unless explicitly silenced.
# 2     I am doing well, how about you?              I am also good.
# 3    What kind of movies do you like?          Alice in Wonderland
# 4                               Hello                           Hi

# %%
# import the nltk libraries
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# import the regular expression library
import re

# Create a function to clean the Questions and Answers
def clean_text(text):
    
    # clean the text
    res = text.lower()
    res = re.sub(r"i'm", "i am", res)
    res = re.sub(r"he's", "he is", res)
    res = re.sub(r"she's", "she is", res)
    res = re.sub(r"i'll", "i will", res)
    res = re.sub(r"it's", "it is", res)
    res = re.sub(r"that's", "that is", res)
    res = re.sub(r"where's", "where is", res)
    res = re.sub(r"how's", "how is", res)
    res = re.sub(r"\'ll", " will", res)
    res = re.sub(r"\'ve", " have", res)
    res = re.sub(r"\'re", " are", res)
    res = re.sub(r"\'d", " would", res)
    res = re.sub(r"\'re", " are", res)
    res = re.sub(r"won't", "will not", res)
    res = re.sub(r"can't", "cannot", res)
    res = re.sub(r"n't", " not", res)
    res = re.sub(r"n'", "ng", res)
    res = re.sub(r"'bout", "about", res)
    res = re.sub(r"'til", "until", res)
    res = re.sub("[\(\[].*?[\)\]]", "", res)
    res = re.sub(r"{.*}", "", res)
    res = re.sub(r"  ", " ", res)
    res = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", res)

    # return the clean text
    return res

# %%
# clean all the question

# initialize the index
index = 0

# clean and store the result
for question in df['Questions']:

    # clean each question
    question = clean_text(question)

    # store each question
    df['Questions'][index] = question

    # increament the index
    index += 1

# %%
# clean all the answers

# initialize the index
index = 0

# clean and store the result
for answer in df['Answers']:

    # clean each answer
    answer = clean_text(answer)

    # store each answer
    df['Answers'][index] = answer

    # increament the index
    index += 1

# %%
df.head()
# Out:
#                            Questions                     Answers
# 0            what are you working on          i am baking a cake
# 1  errors should never pass silently  unless explicitly silenced
# 2      i am doing well how about you              i am also good
# 3    what kind of movies do you like         alice in wonderland
# 4                              hello                          hi

# %%
# convert this file to csv file
df.to_csv('/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Final Datasets/2. Normal QA Preprocessed.csv')

# %%
# file successfully exported to the mentioned path
# path = /content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Final Datasets/2. Normal QA Preprocessed.csv

# %%
# PRE - PROCESSING IS DONE!!!!
