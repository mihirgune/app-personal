# %%
# mount the drive to access files which are on drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# get the path
path = "/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Main_Data/COVID_QA.csv"

# %%
# importing pandas
import pandas as pd

# loading the dataframe
df = pd.read_csv(path)

# check for the data
df.head()
# Out:
#    Unnamed: 0  ...                                            Answers
# 0           0  ...  Mother-to-child transmission (MTCT) is the mai...
# 1           1  ...  DC-SIGNR plays a crucial role in MTCT of HIV-1...
# 2           2  ...  more than 400,000 children were infected world...
# 3           3  ...  High copy numbers of CCL3L1, a potent HIV-1 su...
# 4           4  ...  Dendritic cell-specific ICAM-grabbing non-inte...
#
# [5 rows x 3 columns]

# %%
# delete the column "Unnamed : 0"
df = df.drop(['Unnamed: 0'], axis=1)

# %%
# check for the result
df.head()
# Out:
#                                            Questions                                            Answers
# 0  What is the main cause of HIV-1 infection in c...  Mother-to-child transmission (MTCT) is the mai...
# 1  What plays the crucial role in the Mother to C...  DC-SIGNR plays a crucial role in MTCT of HIV-1...
# 2  How many children were infected by HIV-1 in 20...  more than 400,000 children were infected world...
# 3  What is the role of C-C Motif Chemokine Ligand...  High copy numbers of CCL3L1, a potent HIV-1 su...
# 4        What is DC-GENR and where is  it expressed?  Dendritic cell-specific ICAM-grabbing non-inte...

# %%
# import the nltk libraries
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# import the regular expression library
import re

# Create a function to clean the Questions and Answers
def clean_text(text):
    
    # clean the text
    res = text.lower()
    res = re.sub(r"i'm", "i am", res)
    res = re.sub(r"he's", "he is", res)
    res = re.sub(r"she's", "she is", res)
    res = re.sub(r"i'll", "i will", res)
    res = re.sub(r"it's", "it is", res)
    res = re.sub(r"that's", "that is", res)
    res = re.sub(r"where's", "where is", res)
    res = re.sub(r"how's", "how is", res)
    res = re.sub(r"\'ll", " will", res)
    res = re.sub(r"\'ve", " have", res)
    res = re.sub(r"\'re", " are", res)
    res = re.sub(r"\'d", " would", res)
    res = re.sub(r"\'re", " are", res)
    res = re.sub(r"won't", "will not", res)
    res = re.sub(r"can't", "cannot", res)
    res = re.sub(r"n't", " not", res)
    res = re.sub(r"n'", "ng", res)
    res = re.sub(r"'bout", "about", res)
    res = re.sub(r"'til", "until", res)
    res = re.sub("[\(\[].*?[\)\]]", "", res)
    res = re.sub(r"{.*}", "", res)
    res = re.sub(r"  ", " ", res)
    res = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", res)

    # return the clean text
    return res

# %%
# clean all the question

# initialize the index
index = 0

# clean and store the result
for question in df['Questions']:

    # clean each question
    question = clean_text(question)

    # store each question
    df['Questions'][index] = question

    # increament the index
    index += 1

# %%
# clean all the answers

# initialize the index
index = 0

# clean and store the result
for answer in df['Answers']:

    # clean each answer
    answer = clean_text(answer)

    # store each answer
    df['Answers'][index] = answer

    # increament the index
    index += 1

# %%
df.head()
# Out:
#                                            Questions                                            Answers
# 0  what is the main cause of hiv1 infection in ch...  mothertochild transmission is the main cause o...
# 1  what plays the crucial role in the mother to c...  dcsignr plays a crucial role in mtct of hiv1 a...
# 2  how many children were infected by hiv1 in 200...  more than 400000 children were infected worldw...
# 3  what is the role of cc motif chemokine ligand ...  high copy numbers of ccl3l1 a potent hiv1 supp...
# 4           what is dcgenr and where is it expressed  dendritic cellspecific icamgrabbing nonintegri...

# %%
# convert this file to csv file
df.to_csv('/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Final Datasets/1. COVID-QA Preprocessing.csv')

# %%
# file successfully exported to the mentioned path
# path = /content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Final Datasets/1. COVID-QA Preprocessing.csv

# %%
# PRE - PROCESSING IS DONE!!!!
