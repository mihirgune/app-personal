# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install import_ipynb

# %%
import import_ipynb
import sys
path_file = "/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Pre-processing of Data"
sys.path.insert(0,path_file)

# %%
sys.path
# Out:
# ['/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Pre-processing of Data',
#  '/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Pre-processing of Data/CovidPreprocessing.ipynb',
#  '/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Pre-processing of Data/CovidPreprocessing.ipynb',
#  '/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Pre-processing of Data/CovidPreprocessing.ipynb',
#  '/content/drive/My Drive/2020_Intern_03_VIIT_03_Chatbot/Coding Part (Implementation)/Database and JSON/Pre-processing of Data/1. COVID-QA Preprocessing.ipynb',
#  '',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
# ...

# %%
from CovidPreprocessing import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-1bb036234ad1> in <module>()
# ----> 1 from CovidPreprocessing import *
#
# ModuleNotFoundError: No module named 'CovidPreprocessing'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
